# %% [markdown]
# # Derivadas superiores

# %% [markdown]
# $f'(x)=\frac{4f\left(x+\frac{h}{2}\right)-f(x+h)-3f(x)}{h}+\frac{h^2}{12}f''(x)+\dots$
#
#
# $f'(x)=\frac{27f\left(x+\frac{h}{2}\right)+f\left(x-\frac{3h}{2}\right)-27f\left(x-\frac{h}{2}\right)-f\left(x+\frac{3h}{2}\right)}{h}\dots$

# %% [markdown]
# # Para la segunda derivada

# %% [markdown]
# La aproximacion central para las segunda deriva es:
#
#
# $f''(x)=\frac{4f\left(x+\frac{h}{2}\right)+4f\left(x-\frac{h}{2}\right)-8f(x)}{h^2} + \Game(h^2)$

# %% [markdown]
# # Derivacion automatica

# %% [markdown]
# ## Numeros de Grassman

# %% [markdown]
# Numero dual
#
# $x = a+\acute{a}d$
#
# con $a$=alma y $\acute{a}$=alma y d como un valor antisimetrico, con $d^2$=0. Para entendimiento simple, $a$ es la funcion, $\acute{a}$ es la derivada y $d$ es un valor complementario, desconocido pero usable.
#
# Por ejemplo, tomando la funcion $f(z)=3z^2-z$
#
# $3z^2 - z = (3+0d)(z+d) - (z+d)$
#
# $= 3(z^2 + 2zd +d^2) - (z+d)$
#
# pero $d^2=0$, entonces:
#
# $=3(z^2+2zd) - (z+d)$
#
# $=3z^2 + 6zd - z - d$
#
# reacomodando:
#
# $(3z^2 - z) + (6z-1)d$
#
# $\frac{3z^2 - z}{f(z)} + (6z-1)d$
#
# donde:
#
# $a=\frac{3z^2 - z}{f(z)}$
#
# $\acute{a}=6z-1$
#
# Al final, $\acute{a}=6z-1$ es la derivada de la funcion inicial $f(z)=3z^2-z$.

# %% [markdown]
# Ejercicio:
#
# Hallar la derivada de la funcion $f(z)=\frac{(z+2)(z-3)}{z-4}$

# %% [markdown]
# https://culturacientifica.com/2022/12/21/valentina-borok-una-reconocida-especialista-en-ecuaciones-en-derivadas-parciales/
#
# https://aprendergratis.es/cursos-online/curso-de-simulaciones-usando-python/
#
# https://www.coursera.org/learn/computers-waves-simulations?irgwc=1&utm_medium=partners&utm_source=impact&utm_campaign=2523421&utm_content=b2c

# %%
import numpy as np
import sympy as sy
import matplotlib.pyplot as plt

import math

import mpmath as mp


from sympy import *
from sympy.plotting import plot
from sympy.abc import x

init_printing()

# %%
z=sy.symbols('z')

f=((z+2)*(z-3))/(z-4)

# %%
f
# Out:
# (z - 3)⋅(z + 2)
# ───────────────
#      z - 4

# %%
df=diff(f,z)

df
# Out:
# z - 3   z + 2   (z - 3)⋅(z + 2)
# ───── + ───── - ───────────────
# z - 4   z - 4              2
#                     (z - 4)

# %%
def gp(x,y):
    return [x[0]*y[0], x[0]*y[1] + x[1]*y[0]] #s

# %%
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
# Aqui colocamos el dominio de X e Y y su resolucion, por ejemplo usamos las siguiente:
X = np.arange(0, 0.2, 0.01) # x in [0, 0.2] con resolucion 0.01.
Y = np.arange(0, 0.2, 0.01) # y in [0, 0.2] con resolucion 0.01.
X, Y = np.meshgrid(X, Y)
Z = np.sqrt(1/5 - X ** 2 - Y ** 2)  # obtenemos valores de Z.

# Graficar la superficie.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-1882290fbf4c> in <module>
#       7
#       8 fig = plt.figure()
# ----> 9 ax = fig.gca(projection='3d')
#      10
#      11 # Make data.
#
# TypeError: gca() got an unexpected keyword argument 'projection'

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generar datos (ejemplo)
x_data = np.linspace(0, 10, 100)
y_data = np.sin(x_data)
z_data = np.cos(x_data)

# Crear la figura y el eje 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar los datos
ax.plot(x_data, y_data, z_data, color='b', marker='o', linestyle='-', markersize=5)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Gráfica en 3D')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984)
    return z

# Generar datos para la gráfica
x = np.linspace(-10000, 10000, 100)
y = np.linspace(-10000, 10000, 100)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Crear la figura y el eje 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984)/18195840.0000004
    return z

# Generar datos para la gráfica
x = np.linspace(-1000, 1000, 100)
y = np.linspace(-1000, 1000, 100)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Crear la figura y el eje 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Ajustar el rango del eje Z
ax.set_zlim(-100, 100)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984)
    return z

# Generar datos para la gráfica
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Crear la figura y el eje 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Ajustar el rango del eje Z
ax.set_zlim(0, 10)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984) / 53187839.999984
    return z

# Generar datos para la gráfica
x = np.linspace(-100, 100, 10)
y = np.linspace(-100, 100, 10)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Crear la figura y el eje 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Ajustar el rango del eje Z
ax.set_zlim(-5, 5)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984) / 531878.39999984
    return z

# Generar datos para la gráfica
x = np.linspace(-100, 100, 10)
y = np.linspace(-100, 100, 10)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Crear la figura y el eje 3D con un tamaño mayor
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Ajustar el rango del eje Z
ax.set_zlim(0, 100)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984) / 53187839.999984
    return z

# Generar datos para la gráfica
x = np.linspace(-50, 50, 10)
y = np.linspace(-50, 50, 10)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Crear la figura y el eje 3D con un tamaño mayor
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Ajustar el rango del eje Z
ax.set_zlim(-5, 10)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Rotar la gráfica 45 grados a la derecha
ax.view_init(elev=10, azim=30)

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984) / 53187839.999984
    return z

# Generar datos para la gráfica
x = np.linspace(-10000, 10000, 100)
y = np.linspace(-10000, 10000, 100)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Crear la figura y el eje 3D con un tamaño mayor
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Obtener los límites de los datos
x_min, x_max = np.min(x), np.max(x)
y_min, y_max = np.min(y), np.max(y)
z_min, z_max = np.min(z), np.max(z)

# Ajustar los límites de los ejes
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_zlim(z_min, z_max)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Rotar la gráfica 30 grados a la derecha
ax.view_init(elev=20, azim=-30)

# Mostrar la gráfica
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Definir la ecuación
def equation(x, y):
    z = (-1399680.00000003*x**2 + 1.5965468946888e-7*x*y - 5598720.00000005*x +
         16796159.9999985*x + 1399680.00000013*y**2 - 5598720.00000009*y +
         13996799.9999993*y - 1.27942456629171e-8*y**2 + 18195840.0000004*y - 53187839.9999984) / 53187839.999984
    return z

# Generar datos para la gráfica
x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)
x, y = np.meshgrid(x, y)
z = equation(x, y)

# Punto A
point_A = (1, 2, 3)
point_B=(2,1,7)

# Crear la figura y el eje 3D con un tamaño mayor
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie
ax.plot_surface(x, y, z, cmap='viridis')

# Graficar el punto A
ax.scatter(*point_A, color='red', label='Punto A')
ax.scatter(*point_B, color='blue', label='Punto B')


# Obtener los límites de los datos
x_min, x_max = np.min(x), np.max(x)
y_min, y_max = np.min(y), np.max(y)
z_min, z_max = np.min(z), np.max(z)

# Ajustar los límites de los ejes
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_zlim(z_min, z_max)

# Personalizar la gráfica
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.set_title('Superficie tridimensional')

# Rotar la gráfica 30 grados a la derecha
ax.view_init(elev=20, azim=-30)

# Mostrar la gráfica
plt.show()
